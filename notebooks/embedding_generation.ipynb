# %%
# %load_ext autoreload
# %autoreload 2

# %%
from embeddings.igdb_metadata import get_games_count

get_games_count()
# Out:
# 9353

# %%
from embeddings.igdb_metadata import download_data

download_data()
# Out:
# 📦 Descargados 500 juegos... (Último ID: 719)
# 📦 Descargados 1000 juegos... (Último ID: 1405)
# 📦 Descargados 1500 juegos... (Último ID: 2266)
# 📦 Descargados 2000 juegos... (Último ID: 3203)
# 📦 Descargados 2500 juegos... (Último ID: 4534)
# 📦 Descargados 3000 juegos... (Último ID: 5923)
# 📦 Descargados 3500 juegos... (Último ID: 7307)
# 📦 Descargados 4000 juegos... (Último ID: 8603)
# 📦 Descargados 4500 juegos... (Último ID: 10530)
# 📦 Descargados 5000 juegos... (Último ID: 13138)
# 📦 Descargados 5500 juegos... (Último ID: 18166)
# 📦 Descargados 6000 juegos... (Último ID: 21527)
# 📦 Descargados 6500 juegos... (Último ID: 27931)
# 📦 Descargados 7000 juegos... (Último ID: 51297)
# 📦 Descargados 7500 juegos... (Último ID: 99302)
# 📦 Descargados 8000 juegos... (Último ID: 121754)
# 📦 Descargados 8500 juegos... (Último ID: 145319)
# 📦 Descargados 9000 juegos... (Último ID: 238782)
# 📦 Descargados 9353 juegos... (Último ID: 396231)
# ✅ ¡Descarga completada con éxito!

# %%
from embeddings.steam_reviews import download_reviews

download_reviews()
# Out:
# 📦 Descargadas reseñas para 2550 juegos... (Último ID: 24881)
# 📦 Descargadas reseñas para 2560 juegos... (Último ID: 25214)
# 📦 Descargadas reseñas para 2570 juegos... (Último ID: 25577)
# 📦 Descargadas reseñas para 2580 juegos... (Último ID: 25656)
# 📦 Descargadas reseñas para 2590 juegos... (Último ID: 25812)
# 📦 Descargadas reseñas para 2600 juegos... (Último ID: 25962)
# 📦 Descargadas reseñas para 2610 juegos... (Último ID: 26202)
# 📦 Descargadas reseñas para 2620 juegos... (Último ID: 26399)
# 📦 Descargadas reseñas para 2630 juegos... (Último ID: 26534)
# 📦 Descargadas reseñas para 2640 juegos... (Último ID: 26612)
# 📦 Descargadas reseñas para 2650 juegos... (Último ID: 26674)
# 📦 Descargadas reseñas para 2660 juegos... (Último ID: 26809)
# 📦 Descargadas reseñas para 2670 juegos... (Último ID: 26869)
# 📦 Descargadas reseñas para 2680 juegos... (Último ID: 26972)
# 📦 Descargadas reseñas para 2690 juegos... (Último ID: 27091)
# ...

# %%
from embeddings.steam_reviews import filter_reviews

filter_reviews()

# %%
from embeddings.steam_reviews import get_filtered_reviews

filtered_reviews = get_filtered_reviews()
print(len(filtered_reviews))
# Out:
# 4012
