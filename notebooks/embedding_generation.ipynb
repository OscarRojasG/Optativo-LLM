# %%
# %load_ext autoreload
# %autoreload 2

# %%
from embeddings.steam_reviews import get_steam_reviews

get_steam_reviews("1172470")
# Out:
# ['Gran TryHard de Movimiento.. con Bastantes Coleccionables.\n\nla historia de cada personaje solo da un sentido a cada uno pero no contribuye en relevante al juego.\n\ncontiene una cantidad más que aceptable de personajes cada uno con surtido de habilidades que se adaptan al modo de juego a gusto del consumidor. los retrocesos de las armas son del demonio y aunque no cuestan a la memoria las podemos pasar con mejoras para cada arma.\n\nsu responsiva a los controles y la propia optimización ayuda bastante a la experiencia de juego al tratarse de un genero centrado en los movimientos a través del campo de batalla pero que se desaprovecha bastante al contener limitados modos de juegos, por ejemplos se pudieran incorporar algo similar a captura de bandera ó ataque y defensa, incluso un modo campaña co-op iria increíble.\n\ncontiene una basta cantidad de objetos coleccionables con garantía pero a la costumbre son de pago y algo costosos a mi parecer, no obstante las recompensas a través 
# ...

# %%
from embeddings.igdb_metadata import get_igdb_metadata

get_igdb_metadata()
# Out:
# [{'id': 78869,
#   'name': 'Giana Sisters: Twisted Dreams - Owltimate Edition',
#   'rating': 83.0,
#   'summary': 'Giana Sisters: Twisted Dreams – Owltimate Edition offers classic 2D platforming fun in meticulously detailed 3D environments. Players can turn cute Giana into a punk version of herself at the press of a button, transforming the game’s star, the soundtrack and even the world.\n\nThis overhaul isn’t merely cosmetic: Giana’s punk persona is a critical to overcoming obstacles and solving particularly tricky situations. In her sweet incarnation, Giana whirls gracefully over obstacles and opponents, but when ‘punked up’ she smashes through stone blocks with mighty dashes and can master her environment by bouncing off walls.'},
#  {'id': 5850,
#   'name': 'Grand Theft Auto: The Trilogy',
#   'rating': 88.09459346454814,
# ...
