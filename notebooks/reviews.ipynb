# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Cargar el modelo
from models.LLM import ChatOllama

model = ChatOllama(
    model="gemma4:e2b",
    temperature=0
)

# %%
from data.attributes import generate_attributes

generate_attributes(model, max_workers=5)
