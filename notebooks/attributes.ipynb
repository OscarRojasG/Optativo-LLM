# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Cargar el modelo
from models.LLM import ChatOllama

model = ChatOllama(
    model="gemma4:e2b",
    temperature=0
)

# %%
from data.attributes import generate_attributes

generate_attributes(model)
# Out:
# Total de juegos con reseñas: 4012
# Total de juegos con atributos: 1
# Juegos pendientes: 4011
# [1/4011] | 0.02% completado | Finalizado: 9878
# [2/4011] | 0.05% completado | Finalizado: 139403
# [3/4011] | 0.07% completado | Finalizado: 51448
# [4/4011] | 0.10% completado | Finalizado: 6451
# [5/4011] | 0.12% completado | Finalizado: 152246
# Guardando...
